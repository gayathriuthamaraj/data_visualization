# %%
from dash import Dash, dcc, html
import plotly.express as px


app = Dash(__name__)

# Simple figure using Plotly Express' built-in iris dataset
fig = px.scatter(
    px.data.iris(),
    x="sepal_width",
    y="sepal_length",
    color="species",
    title="Dash Hello World: Iris Scatter",
)

app.layout = html.Div([
    html.H3("Dash Hello World"),
    dcc.Graph(figure=fig),
])


if __name__ == "__main__":
    app.run_server(debug=True)
# Out:
# ---------------------------------------------------------------------------
# ObsoleteAttributeException                Traceback (most recent call last)
# Cell In[2], line 23
#      16 app.layout = html.Div([
#      17     html.H3("Dash Hello World"),
#      18     dcc.Graph(figure=fig),
#      19 ])
#      22 if __name__ == "__main__":
# ---> 23     app.run_server(debug=True)
#
# File c:\Users\gayat\anaconda3\Lib\site-packages\dash\_obsolete.py:22, in ObsoleteChecker.__getattr__(self, name)
#      20 if name in self._obsolete_attributes:
#      21     err = self._obsolete_attributes[name]
# ---> 22     raise err.exc(err.message)
#      23 return getattr(self.__dict__, name)
#
# ObsoleteAttributeException: app.run_server has been replaced by app.run
