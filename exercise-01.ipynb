# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

# %% [markdown]
# **Bar Plot**
#
# Plot a bar chart comparing the total lipid fat content for each milk type (Description).

# %%
"""import csv

rows = []
#Don't need to do this if we use pandas as it automatically does numeric conversions
with open('food.csv', newline='') as csvfile:
    reader = csv.reader(csvfile)
    header = next(reader)  # Save the header
    for row in reader:
        # Only process rows that have data
        if row:  # skip empty rows
            new_row = row[:2] + [str(float(x)) for x in row[2:]]
            rows.append(new_row)

with open('food_cleaned.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(header)
    writer.writerows(rows)"""
# Out:
# "import csv\n\nrows = []\n#Don't need to do this if we use pandas as it automatically does numeric conversions\nwith open('food.csv', newline='') as csvfile:\n    reader = csv.reader(csvfile)\n    header = next(reader)  # Save the header\n    for row in reader:\n        # Only process rows that have data\n        if row:  # skip empty rows\n            new_row = row[:2] + [str(float(x)) for x in row[2:]]\n            rows.append(new_row)\n\nwith open('food_cleaned.csv', 'w', newline='') as csvfile:\n    writer = csv.writer(csvfile)\n    writer.writerow(header)\n    writer.writerows(rows)"

# %%
"""for category in df["Category"].unique():
    subset = df[df["Category"] == category]
    plt.figure(figsize=(10,4))
    sns.barplot(x="Description", y="Data.Cholesterol", data=subset)
    plt.title(f"Cholesterol Content for {category}")
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.show()"""
# Out:
# 'for category in df["Category"].unique():\n    subset = df[df["Category"] == category]\n    plt.figure(figsize=(10,4))\n    sns.barplot(x="Description", y="Data.Cholesterol", data=subset)\n    plt.title(f"Cholesterol Content for {category}")\n    plt.xticks(rotation=90)\n    plt.tight_layout()\n    plt.show()'

# %%
df = pd.read_csv("food_cleaned.csv")

# %%
sns.swarmplot(x = "Category", y = "Data.Carbohydrate", hue = "Data.Protein", data = df)
plt.legend(bbox_to_anchor = (1,1), loc = "upper left")
plt.hot()
plt.show()
# Out:
# c:\Users\gayat\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 80.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\gayat\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 75.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\gayat\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 66.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\gayat\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 25.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
daf = df[["Category", "Data.Cholesterol"]]

# %%
plt.hist(daf["Data.Cholesterol"], bins = 40)
# Out:
# (array([6.096e+03, 7.550e+02, 8.200e+01, 6.500e+01, 6.300e+01, 5.000e+00,
#         2.000e+00, 2.000e+00, 1.000e+00, 1.000e+00, 3.000e+00, 1.000e+00,
#         0.000e+00, 3.000e+00, 2.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([   0.  ,   76.85,  153.7 ,  230.55,  307.4 ,  384.25,  461.1 ,
#          537.95,  614.8 ,  691.65,  768.5 ,  845.35,  922.2 ,  999.05,
#         1075.9 , 1152.75, 1229.6 , 1306.45, 1383.3 , 1460.15, 1537.  ,
#         1613.85, 1690.7 , 1767.55, 1844.4 , 1921.25, 1998.1 , 2074.95,
#         2151.8 , 2228.65, 2305.5 , 2382.35, 2459.2 , 2536.05, 2612.9 ,
#         2689.75, 2766.6 , 2843.45, 2920.3 , 2997.15, 3074.  ]),
#  <BarContainer object of 40 artists>)
