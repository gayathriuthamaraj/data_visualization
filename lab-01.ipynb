# %%
print(1)
# Out:
# 1

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]
plt.plot(x, y, marker='*', linestyle = '-', color='b')
plt.title('Sample Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.grid(True)
plt.savefig('sample_plot.png', dpi=300, bbox_inches='tight')

# %%
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]
z = [1, 4, 9, 16, 25]
plt.plot(x, y, z, marker='*', linestyle = '-', color='b')
plt.title('Sample Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.grid(True)
plt.savefig('sample_plot.png', dpi=300, bbox_inches='tight')
