# %% [markdown]
# Case-study

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("dino_clean.csv")
df.head()
# Out:
#                 name            pronunciation               meaning  \
# 0           Aardonyx                ar-don-ix          'Earth claw'
# 1        Abelisaurus       ah-BEEL-ee-sore-us       'Abel's lizard'
# 2      Achelousaurus        ah-KEL-oo-SORE-us    'Achelous' lizard'
# 3       Achillobator         a-kil-oh-bah-tor       'Achilles hero'
# 4  Acrocantho-saurus  ah-kroh-kan-tho-SORE-us  'high-spined lizard'
#
#              type length weight         diet teeth food how_moved  ... site3  \
# 0     prosauropod   8.0m    NaN  herbivorous   NaN  NaN       NaN  ...   NaN
# 1  large theropod   9.0m    NaN  carnivorous   NaN  NaN       NaN  ...   NaN
# 2     ceratopsian   6.0m    NaN  herbivorous   NaN  NaN       NaN  ...   NaN
# 3  large theropod   5.0m    NaN  carnivorous   NaN  NaN       NaN  ...   NaN
# 4  large theropod  12.0m    NaN  carnivorous   NaN  NaN       NaN  ...   NaN
#
#   site4               era                 time_range  start    end  \
# ...

# %%
df["when_it_lived"].head()
# Out:
# 0      Early Jurassic, 199-189 million years ago
# 1       Late Cretaceous, 74-70 million years ago
# 2       Late Cretaceous, 83-70 million years ago
# 3       Late Cretaceous, 99-84 million years ago
# 4    Early Cretaceous, 115-105 million years ago
# Name: when_it_lived, dtype: object
