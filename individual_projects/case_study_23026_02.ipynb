# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
x  = np.arange(1,11)
plt.plot(x,np.log(x))

# %%
df = pd.read_csv(r"C:\Users\gayat\DATA VISUALIZATION\data_visualization\individual_projects\dino_clean.csv")
df.head()
# Out:
#                 name            pronunciation               meaning  \
# 0           Aardonyx                ar-don-ix          'Earth claw'
# 1        Abelisaurus       ah-BEEL-ee-sore-us       'Abel's lizard'
# 2      Achelousaurus        ah-KEL-oo-SORE-us    'Achelous' lizard'
# 3       Achillobator         a-kil-oh-bah-tor       'Achilles hero'
# 4  Acrocantho-saurus  ah-kroh-kan-tho-SORE-us  'high-spined lizard'
#
#              type length weight         diet teeth food how_moved  ...  \
# 0     prosauropod   8.0m    NaN  herbivorous   NaN  NaN       NaN  ...
# 1  large theropod   9.0m    NaN  carnivorous   NaN  NaN       NaN  ...
# 2     ceratopsian   6.0m    NaN  herbivorous   NaN  NaN       NaN  ...
# 3  large theropod   5.0m    NaN  carnivorous   NaN  NaN       NaN  ...
# 4  large theropod  12.0m    NaN  carnivorous   NaN  NaN       NaN  ...
#
#                 era                 time_range  start    end weight_clean  \
# ...
